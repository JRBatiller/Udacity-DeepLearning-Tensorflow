# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# WARNING:tensorflow:From <ipython-input-5-3b42a02b2811>:45: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.713816
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.818170
# Minibatch accuracy: 50.0%
# Validation accuracy: 50.2%
# Minibatch loss at step 100: 0.976587
# Minibatch accuracy: 68.8%
# Validation accuracy: 65.9%
# Minibatch loss at step 150: 0.330624
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 200: 0.815683
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 250: 1.089344
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 300: 0.341344
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 0.459094
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 400: 0.178196
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.826349
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.628678
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 1.049545
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 600: 0.315610
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.916185
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 700: 1.097262
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.043044
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 800: 0.537282
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 850: 0.928300
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 900: 0.621869
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 950: 0.601559
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.399596
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Test accuracy: 89.6%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
graph = tf.Graph()
dimension_list = [[patch_size, patch_size, num_channels, depth], [patch_size, patch_size, depth, depth], [image_size//4*image_size//4*depth, num_hidden], [num_hidden, num_labels]]

with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    def generate_variables(dimension_list):
        weights = []
        biases = []
        for i in range(len(dimension_list)):
            weights.append(tf.Variable(tf.truncated_normal(
                dimension_list[i], stddev=0.1)))
            biases.append(tf.Variable(tf.zeros([dimension_list[i][-1]])))
        return weights, biases

    weights, biases = generate_variables(dimension_list)

    # Model.
    def model(data):
        conv = tf.nn.conv2d(data, weights[0], [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + biases[0])
        pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        conv = tf.nn.conv2d(pool, weights[1], [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + biases[1])
        pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pool.get_shape().as_list()
        reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, weights[2]) + biases[2])
        return tf.matmul(hidden, weights[3]) + biases[3]

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))

    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))


#### SESSION ###########

num_steps = 1001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.332483
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.4%
# Minibatch loss at step 50: 1.861295
# Minibatch accuracy: 25.0%
# Validation accuracy: 55.5%
# Minibatch loss at step 100: 1.066858
# Minibatch accuracy: 56.2%
# Validation accuracy: 54.0%
# Minibatch loss at step 150: 0.403985
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 200: 1.015415
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 250: 1.082801
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 300: 0.380839
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 350: 0.413478
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 400: 0.175090
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 450: 0.987780
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 500: 0.587721
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 550: 0.789307
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 600: 0.338415
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 650: 0.824987
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 700: 0.811482
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 750: 0.029369
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 800: 0.676697
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 850: 0.815310
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 900: 0.534566
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 950: 0.446566
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 1000: 0.317390
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Test accuracy: 91.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
######## RESHAPE #######
train_dataset = np.pad(train_dataset, ((0, 0), (2, 2), (2, 2), (0, 0)), 'constant')
valid_dataset = np.pad(valid_dataset, ((0, 0), (2, 2), (2, 2), (0, 0)), 'constant')
test_dataset = np.pad(test_dataset, ((0, 0), (2, 2), (2, 2), (0, 0)), 'constant')

print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)

image_size = 32
num_labels = 10
num_channels = 1  # grayscale
batch_size = 128 #increased batch size by a lot slows own processing but increases accuracy
patch_size = 5
depth_1 = 6
depth_2 = 16
num_hidden = 120


graph = tf.Graph()
dimension_list = [[patch_size, patch_size, num_channels, depth_1], [patch_size, patch_size, depth_1, depth_2], [25*depth_2, num_hidden], [num_hidden, num_labels]]
print(dimension_list)
with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    global_step = tf.Variable(0)

    # Variables.
    def generate_variables(dimension_list):
        weights = []
        biases = []
        for i in range(len(dimension_list)):
            weights.append(tf.Variable(tf.truncated_normal(
                dimension_list[i], mean=0, stddev=0.1)))
            biases.append(tf.Variable(tf.zeros([dimension_list[i][-1]])))
        return weights, biases

    weights, biases = generate_variables(dimension_list)

    # Model.
    def model(data, prob=1.0):
        # 32x32
        #I can probably use same padding and not pad the images
        c1 = tf.nn.conv2d(data, weights[0], [1, 1, 1, 1], padding='VALID')
        c1 = tf.nn.relu(c1 + biases[0])
        c1 = tf.nn.dropout(c1, prob)
        # 28x28
        s2 = tf.nn.max_pool(c1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        # 14x14
        c3 = tf.nn.conv2d(s2, weights[1], [1, 1, 1, 1], padding='VALID')
        c3 = tf.nn.relu(c3 + biases[1])
        c3 = tf.nn.dropout(c3, prob)
        # 10x10
        s4 = tf.nn.max_pool(c3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        # 5x5
        shape = s4.get_shape().as_list()
        c5 = tf.reshape(s4, [shape[0], shape[1] * shape[2] * shape[3]])
        c5 = tf.nn.relu(tf.matmul(c5, weights[2]) + biases[2])
        c5 = tf.nn.dropout(c5, prob)
        return tf.matmul(c5, weights[3]) + biases[3]

    # Training computation.
    logits = model(tf_train_dataset, 0.5)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))

    # Optimizer.
    #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    #learning_rate = tf.train.exponential_decay(0.5, global_step, 5000, 0.8, staircase=True)
    #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    rate=0.001
    optimizer = tf.train.AdamOptimizer(learning_rate=rate).minimize(loss)
    #training_operation = optimizer.minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))


#### SESSION ###########

num_steps = 2001
#num_steps = 20001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Training set (200000, 32, 32, 1) (200000, 10)
# Validation set (10000, 32, 32, 1) (10000, 10)
# Test set (10000, 32, 32, 1) (10000, 10)
# [[5, 5, 1, 6], [5, 5, 6, 16], [400, 120], [120, 10]]
# Initialized
# Minibatch loss at step 0: 2.491825
# Minibatch accuracy: 8.6%
# Validation accuracy: 10.9%
# Minibatch loss at step 50: 1.172338
# Minibatch accuracy: 60.9%
# Validation accuracy: 71.9%
# Minibatch loss at step 100: 0.921085
# Minibatch accuracy: 72.7%
# Validation accuracy: 79.3%
# Minibatch loss at step 150: 0.916683
# Minibatch accuracy: 73.4%
# Validation accuracy: 81.1%
# Minibatch loss at step 200: 0.722769
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.5%
# Minibatch loss at step 250: 0.553121
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 300: 0.734956
# Minibatch accuracy: 77.3%
# Validation accuracy: 83.2%
# Minibatch loss at step 350: 0.457438
# Minibatch accuracy: 85.9%
# Validation accuracy: 83.6%
# Minibatch loss at step 400: 0.759695
# Minibatch accuracy: 74.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 450: 0.540854
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.2%
# Minibatch loss at step 500: 0.444342
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.2%
# Minibatch loss at step 550: 0.791832
# Minibatch accuracy: 75.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 600: 0.682075
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 650: 0.748242
# Minibatch accuracy: 78.9%
# Validation accuracy: 85.2%
# Minibatch loss at step 700: 0.714562
# Minibatch accuracy: 78.9%
# Validation accuracy: 85.3%
# Minibatch loss at step 750: 0.626429
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 800: 0.433198
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.3%
# Minibatch loss at step 850: 0.569636
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 900: 0.645366
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 950: 0.684636
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 1000: 0.767989
# Minibatch accuracy: 75.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 1050: 0.389430
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 1100: 0.586875
# Minibatch accuracy: 80.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 1150: 0.553831
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 1200: 0.497159
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 1250: 0.455216
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 1300: 0.579200
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 1350: 0.574453
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.5%
# Minibatch loss at step 1400: 0.424218
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 1450: 0.466884
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 1500: 0.417302
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.9%
# Minibatch loss at step 1550: 0.516601
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 1600: 0.610413
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 1650: 0.549700
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 1700: 0.400700
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 1750: 0.397033
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.9%
# Minibatch loss at step 1800: 0.594669
# Minibatch accuracy: 79.7%
# Validation accuracy: 87.1%
# Minibatch loss at step 1850: 0.568299
# Minibatch accuracy: 83.6%
# Validation accuracy: 87.2%
# Minibatch loss at step 1900: 0.666273
# Minibatch accuracy: 82.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 1950: 0.372235
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 2000: 0.437496
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.5%
# Test accuracy: 93.5%

# %% [markdown]
# A different structure.
# [[6, 6, 1, 6], [5, 5, 6, 12], [4, 4, 12, 24], [1176, 200], [200, 10]]
# 28x28x1
# 28x28x6
# 14x14x12
# 7x7x24
# 200x1
# 10x1

# %%
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range
import importlib
import notMNIST_methods as nmm
importlib.reload(nmm)
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
    save = pickle.load(f)
    train_dataset = save['train_dataset']
    train_labels = save['train_labels']
    valid_dataset = save['valid_dataset']
    valid_labels = save['valid_labels']
    test_dataset = save['test_dataset']
    test_labels = save['test_labels']
    del save  # hint to help gc free up memory
    print('Training set', train_dataset.shape, train_labels.shape)
    print('Validation set', valid_dataset.shape, valid_labels.shape)
    print('Test set', test_dataset.shape, test_labels.shape)
image_size = 28
num_labels = 10
num_channels = 1  # grayscale
batch_size = 128

train_dataset, train_labels = nmm.reformat_cube(train_dataset, train_labels)
valid_dataset, valid_labels = nmm.reformat_cube(valid_dataset, valid_labels)
test_dataset, test_labels = nmm.reformat_cube(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)


graph = tf.Graph()
dimension_list = [[6,6,1,6],[5,5,6,12],[4,4,12,24],[image_size//4*image_size//4*24, 200], [200, num_labels]]
print(dimension_list)
with graph.as_default():

    # Input data.
    tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    global_step = tf.Variable(0)

    # Variables.
    def generate_variables(dimension_list):
        weights = []
        biases = []
        for i in range(len(dimension_list)):
            weights.append(tf.Variable(tf.truncated_normal(
                dimension_list[i], mean=0, stddev=0.1)))
            biases.append(tf.Variable(tf.zeros([dimension_list[i][-1]])))
        return weights, biases

    weights, biases = generate_variables(dimension_list)

    # Model.
    def model(data, prob=1.0):
        # 28x28x1
        #I can probably use same padding and not pad the images
        c1 = tf.nn.conv2d(data, weights[0], [1, 1, 1, 1], padding='SAME')
        c1 = tf.nn.relu(c1 + biases[0])
        # 28x28x6
        c2 = tf.nn.conv2d(c1, weights[1], [1, 1, 1, 1], padding='SAME')
        c2 = tf.nn.relu(c2 + biases[1])
        c2 = tf.nn.max_pool(c2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        # 14x14x12
        c3 = tf.nn.conv2d(c2, weights[2], [1, 1, 1, 1], padding='SAME')
        c3 = tf.nn.relu(c3 + biases[2])
        c3 = tf.nn.max_pool(c3, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        # 7x7x24
        shape = c3.get_shape().as_list()
        c4 = tf.reshape(c3, [shape[0], shape[1] * shape[2] * shape[3]])
        c5 = tf.nn.relu(tf.matmul(c4, weights[3]) + biases[3])
        c5 = tf.nn.dropout(c5, prob)
        return tf.matmul(c5, weights[4]) + biases[4]

    # Training computation.
    logits = model(tf_train_dataset, 0.75)
    loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels, logits=logits))

    # Optimizer.
    #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    #learning_rate = tf.train.exponential_decay(0.5, global_step, 5000, 0.8, staircase=True)
    #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    rate=0.001
    optimizer = tf.train.AdamOptimizer(learning_rate=rate).minimize(loss)
    #training_operation = optimizer.minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))


#### SESSION ###########

num_steps = 20001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset: batch_data, tf_train_labels: batch_labels}
        _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 100 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % nmm.accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % nmm.accuracy(
                valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % nmm.accuracy(test_prediction.eval(), test_labels))
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)
# [[6, 6, 1, 6], [5, 5, 6, 12], [4, 4, 12, 24], [1176, 200], [200, 10]]
# Initialized
# Minibatch loss at step 0: 2.390055
# Minibatch accuracy: 4.7%
# Validation accuracy: 13.8%
# Minibatch loss at step 100: 0.568279
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.1%
# Minibatch loss at step 200: 0.584950
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.2%
# Minibatch loss at step 300: 0.538516
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 400: 0.447527
# Minibatch accuracy: 83.6%
# Validation accuracy: 86.8%
# Minibatch loss at step 500: 0.271099
# Minibatch accuracy: 93.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 600: 0.497290
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.6%
# Minibatch loss at step 700: 0.456659
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.2%
# Minibatch loss at step 800: 0.261082
# Minibatch accuracy: 89.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 900: 0.473464
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 1000: 0.539453
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 1100: 0.298374
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 1200: 0.305471
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 1300: 0.414895
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 1400: 0.299185
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 1500: 0.245494
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 1600: 0.404861
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 1700: 0.253611
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.8%
# Minibatch loss at step 1800: 0.357894
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.0%
# Minibatch loss at step 1900: 0.429908
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 2000: 0.294559
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 2100: 0.241473
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 2200: 0.311263
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 2300: 0.398367
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
# Minibatch loss at step 2400: 0.326183
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 2500: 0.247660
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 2600: 0.348016
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.6%
# Minibatch loss at step 2700: 0.325518
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 2800: 0.239199
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 2900: 0.244928
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.8%
# Minibatch loss at step 3000: 0.327158
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 3100: 0.235294
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.0%
# Minibatch loss at step 3200: 0.233836
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.0%
# Minibatch loss at step 3300: 0.251597
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.1%
# Minibatch loss at step 3400: 0.245516
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 3500: 0.356180
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 3600: 0.372304
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 3700: 0.386245
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 3800: 0.181469
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.1%
# Minibatch loss at step 3900: 0.380091
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 4000: 0.272752
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 4100: 0.352596
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 4200: 0.246294
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 4300: 0.103701
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.4%
# Minibatch loss at step 4400: 0.232755
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.3%
# Minibatch loss at step 4500: 0.262519
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.1%
# Minibatch loss at step 4600: 0.294582
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 4700: 0.287455
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 4800: 0.300071
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 4900: 0.185832
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 5000: 0.254554
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 5100: 0.253745
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 5200: 0.289302
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 5300: 0.185531
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.3%
# Minibatch loss at step 5400: 0.277151
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.3%
# Minibatch loss at step 5500: 0.223931
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 5600: 0.163923
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 5700: 0.210600
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 5800: 0.252421
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 5900: 0.236456
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 6000: 0.385260
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 6100: 0.225015
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 6200: 0.184591
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 6300: 0.342156
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.5%
# Minibatch loss at step 6400: 0.213168
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.5%
# Minibatch loss at step 6500: 0.265101
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 6600: 0.203063
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 6700: 0.256421
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 6800: 0.197467
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 6900: 0.237630
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 7000: 0.386693
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 7100: 0.182449
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 7200: 0.357154
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 7300: 0.246747
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 7400: 0.251694
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 7500: 0.256086
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 7600: 0.175924
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 7700: 0.247881
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 7800: 0.270857
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.0%
# Minibatch loss at step 7900: 0.197988
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 8000: 0.362659
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 8100: 0.113020
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 8200: 0.137284
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.9%
# Minibatch loss at step 8300: 0.230525
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 8400: 0.174155
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.4%
# Minibatch loss at step 8500: 0.184177
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.5%
# Minibatch loss at step 8600: 0.135971
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 8700: 0.307018
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.5%
# Minibatch loss at step 8800: 0.184869
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 8900: 0.147790
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 9000: 0.299086
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 9100: 0.159869
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 9200: 0.243812
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.4%
# Minibatch loss at step 9300: 0.181493
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 9400: 0.234123
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 9500: 0.275942
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 9600: 0.244680
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 9700: 0.122857
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.8%
# Minibatch loss at step 9800: 0.093025
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 9900: 0.233280
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 10000: 0.216286
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 10100: 0.166102
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 10200: 0.296697
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 10300: 0.278377
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 10400: 0.148544
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 10500: 0.342275
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 10600: 0.170288
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 10700: 0.224683
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 10800: 0.126603
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 10900: 0.161736
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 11000: 0.120748
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 11100: 0.155185
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 11200: 0.182267
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 11300: 0.098323
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 11400: 0.258826
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 11500: 0.212696
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 11600: 0.157778
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 11700: 0.169808
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 11800: 0.167069
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 11900: 0.125670
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 12000: 0.227548
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 12100: 0.107988
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 12200: 0.061767
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 12300: 0.175782
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 12400: 0.113130
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 12500: 0.145760
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 12600: 0.189820
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 12700: 0.236114
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 12800: 0.070703
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.8%
# Minibatch loss at step 12900: 0.211628
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 13000: 0.270688
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 13100: 0.181571
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 13200: 0.136565
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 13300: 0.240062
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 13400: 0.050360
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 13500: 0.200317
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 13600: 0.169502
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 13700: 0.240706
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 13800: 0.130297
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 13900: 0.188447
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 14000: 0.187233
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.1%
# Minibatch loss at step 14100: 0.174498
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 14200: 0.252372
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 14300: 0.131354
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 14400: 0.205895
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 14500: 0.239044
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 14600: 0.122517
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 14700: 0.117933
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 14800: 0.108839
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 14900: 0.136852
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 15000: 0.092489
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 15100: 0.248662
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 15200: 0.208782
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 15300: 0.134112
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 15400: 0.221399
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.9%
# Minibatch loss at step 15500: 0.183067
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 15600: 0.110659
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 15700: 0.154405
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 15800: 0.154111
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 15900: 0.193252
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 16000: 0.098410
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 16100: 0.144334
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 16200: 0.151621
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 16300: 0.242859
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 16400: 0.179387
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 16500: 0.131709
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 16600: 0.187218
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 16700: 0.182716
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 16800: 0.162375
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 16900: 0.091117
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 17000: 0.049784
# Minibatch accuracy: 99.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 17100: 0.125454
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.9%
# Minibatch loss at step 17200: 0.151600
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 17300: 0.142086
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 17400: 0.082698
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.9%
# Minibatch loss at step 17500: 0.045897
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 17600: 0.150169
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 17700: 0.109911
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 17800: 0.195378
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 17900: 0.172333
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 18000: 0.147392
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.1%
# Minibatch loss at step 18100: 0.129387
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.8%
# Minibatch loss at step 18200: 0.186218
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.1%
# Minibatch loss at step 18300: 0.043220
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 18400: 0.081266
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 18500: 0.086039
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.8%
# Minibatch loss at step 18600: 0.145757
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 18700: 0.179390
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 18800: 0.147781
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 18900: 0.236501
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 19000: 0.091275
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.1%
# Minibatch loss at step 19100: 0.142039
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 19200: 0.225508
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.9%
# Minibatch loss at step 19300: 0.173910
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 19400: 0.139348
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 19500: 0.149050
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 19600: 0.159700
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.1%
# Minibatch loss at step 19700: 0.143811
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 19800: 0.118012
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 19900: 0.166111
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 20000: 0.189217
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Test accuracy: 96.8%

# %% [markdown]
# This results in 96.9% accuracy
